# %%
import pandas as pd
import numpy as np

# %%
h = pd.read_csv('data\watermelon3_0_En.csv')

# %%
h
# Out:
#     No.  Color       Root   Knocks   Texture Umbilicus Touch  Density  \
# 0     1  green       curl  heavily  distinct      soft  hard    0.697
# 1     2  black       curl     dull  distinct    sunken  hard    0.774
# 2     3  black       curl  heavily  distinct    sunken  hard    0.634
# 3     4  green       curl     dull  distinct    sunken  hard    0.608
# 4     5  white       curl  heavily  distinct    sunken  hard    0.556
# 5     6  green  lightCurl  heavily  distinct    dimple  soft    0.403
# 6     7  black  lightCurl  heavily      blur    dimple  soft    0.481
# 7     8  black  lightCurl  heavily  distinct    dimple  hard    0.437
# 8     9  black  lightCurl     dull      blur    dimple  hard    0.666
# 9    10  green      stiff    clear  distinct    smooth  soft    0.243
# 10   11  white      stiff    clear     fuzzy    smooth  hard    0.245
# 11   12  white       curl  heavily     fuzzy    smooth  soft    0.343
# ...

# %%
h1 = h[['Density','SugerRatio','Label']]
print(h1)
h1.to_csv('data\watermelon_3a.csv', header=None)
# Out:
#     Density  SugerRatio  Label
# 0     0.697       0.460      1
# 1     0.774       0.376      1
# 2     0.634       0.264      1
# 3     0.608       0.318      1
# 4     0.556       0.215      1
# 5     0.403       0.237      1
# 6     0.481       0.149      1
# 7     0.437       0.211      1
# 8     0.666       0.091      0
# 9     0.243       0.267      0
# 10    0.245       0.057      0
# 11    0.343       0.099      0
# 12    0.639       0.161      0
# 13    0.657       0.198      0
# 14    0.360       0.370      0
# 15    0.593       0.042      0
# 16    0.719       0.103      0
